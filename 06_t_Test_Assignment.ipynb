# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamiim-Iqbal/Simulation-and-Modeling/blob/main/06_t_Test_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as stats #new library
import matplotlib.pyplot as plt

# %%
# Step 1: Define the dataset for 12 obserbations (id/k = 23)
k = 23
np.random.seed(1)
exam_scores = 60 + np.random.randint(0, 16, size=12) + (k % 5)
print("Exam scores:", exam_scores)

# Step 2: Define the population mean (hypothesized mean)
population_mean = 65  # Null Hypothesis (H₀): The average class score is 65

# Step 3: Perform the one-sample t-test
t_statistic, p_value = stats.ttest_1samp(exam_scores, population_mean)
ci = stats.t.interval(0.95, df=len(exam_scores)-1, loc=np.mean(exam_scores), scale=stats.sem(exam_scores))

# Step 4: Display the results
print(f'Sample Mean: {np.mean(exam_scores):.2f}')
print(f'Hypothesized Population Mean: {population_mean:.2f}')
print(f't-Statistic: {t_statistic:.2f}')
print(f'Degrees of Freedom: {len(exam_scores) - 1}')
print(f'p-Value: {p_value:.4f}')
print(f'Confidence Interval: [{ci[0]:.2f}, {ci[1]:.2f}]')
# Out:
# Exam scores: [68 74 75 71 78 72 74 68 78 63 63 64]
# Sample Mean: 70.67
# Hypothesized Population Mean: 65.00
# t-Statistic: 3.60
# Degrees of Freedom: 11
# p-Value: 0.0042
# Confidence Interval: [67.20, 74.13]

# %%
# Step 5: Conclusion
alpha = 0.05  # Significance level
if p_value < alpha:
    print(f'Reject the null hypothesis. The average class score is significantly different from {population_mean:.2f}.')
else:
    print(f'Fail to reject the null hypothesis. The average class score is not significantly different from {population_mean:.2f}.')
# Out:
# Reject the null hypothesis. The average class score is significantly different from 65.00.

# %%
# Step 6: Visualize the data
plt.figure()
plt.bar(1, np.mean(exam_scores), color="skyblue", label='Sample Mean')
plt.errorbar(1, np.mean(exam_scores), yerr=np.std(exam_scores), fmt='k', linewidth=1.5, capsize=5)
plt.axhline(y=population_mean, color='r', linestyle='--', linewidth=1.5, label='Hypothesized Mean')
plt.title('Sample Mean vs Hypothesized Mean')
plt.xlim(0.5, 1.5)
plt.xticks([1], ['Exam Scores'])
plt.ylabel('Mean Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
